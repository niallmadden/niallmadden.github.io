// %% [markdown]
// <h1>Table of Contents<span class="tocSkip"></span></h1>
// <div class="toc"><ul class="toc-item"></ul></div>

// %%
#include <stdio.h>

// %%
%%executable test123
pid_t p=fork();
printf("Hello. pid_d=%d\n", p);
// Out:
// Writing executable to test123

// %%
!./test123
// Out:
// Hello. pid_d=20627
// Hello. pid_d=0

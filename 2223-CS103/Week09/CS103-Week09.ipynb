# %% [markdown]
# # CS102/CS103: Week 09 - Dictionaries <span style='color:green'>(V1.1)</span>
#
#
# **Lecture notes for Week 9 of CS102/CS103, 23+24 November, 2022.**
#
# Dr [Niall Madden](mailto:Niall.Madden@UniversityOfGalway.ie), School of Mathematical and Statistical Sciences,
# University of Galway.
#
# You can find these notes on
#
# * Blackboard (including the xlsx file).
# * as HTML at: [https://www.niallmadden.ie/2223-CS103](https://www.niallmadden.ie/2223-CS103)
# * Jupyter notebook on Binder [https://mybinder.org/v2/gh/niallmadden/2223-cs103/main](https://mybinder.org/v2/gh/niallmadden/2223-cs103/main) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/niallmadden/2223-cs103/main)
#
# * Both formats on Github: [https://github.com/niallmadden/2223-cs103](https://github.com/niallmadden/2223-cs103)
#
#
# ***
#
# <div class="pink"><font size="+1"><em>This notebook was written by Niall Madden, and uses some material from Chapter 11 of <a href="https://greenteapress.com/thinkpython2/html">Think Python</a>.</em></div>

# %% [markdown]
# ## News:
# ### Just one class on Wednesday
# For the rest of the semester, we'll have just one lecture on a Wednesday: 13.00 in MRA-201 (Martin Ryan Annex).

# %% [markdown]
# ### Lab 6 this week
#
# Lab 6 uses a new system for fetching a submitting lab work. Have a look at the video for an explanation, as well as the solution to the first task.
#
# For it, you must use the Jupyter server at  [https://cloudjupyter.universityofgalway.ie/](https://cloudjupyter.universityofgalway.ie/). Check your email for a message from `maths-sto@universityofgalway.ie` with your username and password.
#
# **Deadline**: Friday, 25 Nov at 5pm.

# %% [markdown]
# ### Plans for the rest of the semester
#
# * We have two more weeks of labs. There will be some changes to the venues on Tuesday (6th December) and Wednesday (7th December) - we'll use MY127 instead of AMB-1024 and  BLE-2012 both days. You'll need to bring your own laptop to MY127. If that is a problem, contact Niall.
#
# Labs in the Cairnes Building will go ahead as planned.

# %% [markdown]
# ### Assessment Summary
#
# [ Discuss Thursday]

# %% [markdown]
# # Dictionaries
#
# At the end of our last class, we started learning about using a **dictionary** in Python.
#
# A *dictionary* is a collection of _things_ that are indexed by identifiers that we choose. That is, a **dictionary** is made up of
# * **keys**, which act like indices, but can have just about any value
# * **values** which are associated with the keys
# * Each key is associated with a single value: together they are called a _key:value pair_.

# %% [markdown]
# ## Defining a dictionary
#
# A **dictionary** is made up of
# * **keys**, which act like indices, but can have just about any value
# * **values** which are associated with the keys
# * Each key is associated with a single value: together they are called a _key:value pair_.
# * Its data type is `dict`.

# %% [markdown]
# ### Dictionaries V Lists
#
# **Similarities**
# * Both dictionaries and list store collections of things.
# * Use the `len()` function to find out how many things are stored.
# * If `x` is dictionary or a list, index individual elements using square braces: `x[index]`.

# %% [markdown]
# **Differences**
#
# * A `list` are indexed by integers: `0`, `1`, `2`, ..., `len(x)-1`. (So, they are numbered sequences)
# * A `dict` is indexed by its keys, and these keys can be _anything_

# %% [markdown]
# There are two basic ways to define a dictionary.

# %% [markdown]
# ### Method one: make an empty dictionary and add stuff
#
# The keyword `dict()` can be used to create an empty dictionary. Then we can add `key:value pairs`, one at a time.

# %% [markdown]
# ```pytohn
# x = dict()
# x[key1] = value1
# x[key2] = value2
# ...
# ```

# %% [markdown]
# ### Method two: use `{` and `}`
#
# We can also make a dictionary with the `key:value` pairs. Syntax is:
# ```python
# <dict_name> = { <key_1>: <value_1>, <key_2>: <value_2>, ..., <key_n>: <value_n>}
# ```
# That is:
# * dictionary starts with `{` and ends with `}`.
# * There is a colon (`:`) between each key and its corresponding value.
# * `key:value` pairs are separated by commas.

# %% [markdown]
# ### Example: a dictionary for a dictionary
#
# Let's make a dictionary of computer-related terms. Each key will be a term in English, and its value the corresponding term in Irish (Gaeilge).

# %%
eng2gae = dict() # start with an empty dictionary
eng2gae['variable']="athróg"
eng2gae['byte']="ochtán"
eng2gae['identifier']="aitheantóir"
eng2gae['email']="r-phost"

# %%
eng2gae
# Out:
# {'variable': 'athróg',
#  'byte': 'ochtán',
#  'identifier': 'aitheantóir',
#  'email': 'r-phost'}

# %% [markdown]
# To access a value, use `<dictionary>[key]`. Example:

# %%
print(f"The Irish for byte is {eng2gae['byte']}")
# Out:
# The Irish for byte is ochtán

# %% [markdown]
# Using a non-existent key causes an error:
# ```python
# print(f"The Irish for kilobyte is {eng2gae['kilobyte']}")
#
# Slide Type￼
# ￼
# print(f"The Irish for kilobyte is {eng2gae['kilobyte']}")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 print(f"The Irish for kilobyte is {eng2gae['kilobyte']}")
#
# KeyError: 'kilobyte'
# ```
#
# (Use the `get` method to avoid errors; more later).

# %% [markdown]
# ## Working with dictionaries
#
# Some of the typical tasks we might what to do with a dictionary:
# * Check if a `key` is present
# * Check if a value is present
# * Iterate over the keys are values
# * ...

# %% [markdown]
# ### The `in` operator
#
# When we apply the `in` operator to a dictionary, it applies to keys.

# %%
"byte" in eng2gae
# Out:
# True

# %%
"r-phost" in eng2gae
# Out:
# False

# %% [markdown]
# ### The `.keys()`  and `.values()` methods
#
# The  `.keys()`  and `.values()` methods returns the keys and values as a `list`  (well, not quite lists, but very similar...).

# %%
eng2gae.keys()
# Out:
# dict_keys(['variable', 'byte', 'identifier', 'email'])

# %%
eng2gae.values()
# Out:
# dict_values(['athróg', 'ochtán', 'aitheantóir', 'r-phost'])

# %% [markdown]
# The `values()` method can be used in conjunction with the `in` operator:

# %%
"r-phost" in eng2gae.values()
# Out:
# True

# %% [markdown]
# ### Dictionary methods
#
# There are other methods that can be applied to dictionaries.
#
# Each dictionary `D` supports the following **methods** which are called in the form `D.method(arg)`.
#
# |Method | Effect|
# |---|---|
# |`D.clear()`| deletes all keys (and values)|
# |`D.copy()`| creates a copy|
# |`D.get(key[, default])`|retrieves `D[key]` if `key in D` and `default` (or `None`) otherwise |
# |`D.items()`|return all key-value pairs|
# |`D.keys()`|return all keys|
# |`D.pop(key)`|remove key and return associated value|
# |`D.update(E)`|add all key-value pairs from `E` to `D`|
# |`D.values()`|return all values|

# %% [markdown]
# You can read about these methods yourself. BUt we'll have a quick look at using `.update()`, in part to review how t make a dictionary without using the `dict()` function.
#
# Calling  `D.update(E)` "adds" dictionary `E` to `D`:
# * If a key in `E` and not in `D` that `key:value` pair is added to `D`.
# * If a key in `E` is already in `D`, the `key:value` pair is `D` is _replaced_ by the one from `E`.

# %%
d1 = {1: 'i', 2: 'ii', 3: 'iii', 4: 'iv'}
print(f"d1={d1}")
# Out:
# d1={1: 'i', 2: 'ii', 3: 'iii', 4: 'iv'}

# %%
d2 = {4:'IV', 5:'V'}
print(f"d1={d2}")
# Out:
# d1={4: 'IV', 5: 'V'}

# %%
d1.update(d2)
print(f"d1={d1}")
# Out:
# d1={1: 'i', 2: 'ii', 3: 'iii', 4: 'IV', 5: 'V'}

# %% [markdown]
# # Histograms
#
# This section leads towards "Dictionaries as counters", based on Section 11.2 of Think Python.
#
# ## What is a histogram?
#
# A *histogram* is a representation of a list a data, the counts the occurrence  of each element.

# %% [markdown]
# Example:
# > A group of 12 students did an assignment for which they received a mark of A, B, C, or D. Their scores are listed as `[A,B,A,B,D,C,A,D,A,A,B,A]`. A **histogram** for this data counts the numbers of `A`s, `B`s, `C`s and `D`s, as a table is:
#
# |Score | Freq|
# |--|--|
# |D|2|
# |C|1|
# |B|3|
# |A|6|

# %% [markdown]
# A histogram is also often represented as bar-plot, where the height of the bar represents the frequency.
#
# ![Histgram of garde data](histo.png "Histogram of garde data")

# %% [markdown]
# (In the most general settings, we count the frequency of values in certain _ranges_, but we don't need that today).
#
#
# *Dictionaries* are very useful for representing histograms:
# * the **keys** are things being counted (`A`, `B`, `C` and `D`, in the last example).
# * the **values** are the frequencies.
#
# For example, the table
#
# |Score | Freq|
# |--|--|
# |D|2|
# |C|1|
# |B|3|
# |A|6|
#
# could be represented as
# ```python
# {'A': 6, 'B': 3, 'C': 1, 'D': 2}
# ```

# %% [markdown]
# In this section we want to:
# 1. Write a function which takes a list as input, and returns a dictionary representing the histogram
# 2. Write a function to plot a histogram.

# %% [markdown]
# This function is adapted from Think Python. It works as follows:
# * takes a `list` as an argument.
# * makes an empty `dict`
# * iterate over each `element` of the list
#     * if `element` is not a key in the list, add the pair `element:1`.
#     * if `element` is already a key in the list, add `1` to its value.

# %% [markdown]
# Here is the code for `histogram()` (adapted from Section 11.2 of Think Python).

# %%
def histogram(my_list):
    d = dict()
    for element in my_list:
        if element not in d:
            d[element] = 1
        else:
            d[element] += 1
        # print(d)
    return d

# %% [markdown]
# We'll check if it works:

# %%
scores = ['A','B','A','B','C','D','A','D','A','A','B','A']

# %%
scores_hist = histogram(scores)
print( scores_hist)
# Out:
# {'A': 6, 'B': 3, 'C': 1, 'D': 2}

# %% [markdown]
# ### Plotting histograms
#
# We will plot histograms dictionaries using the `bar()` function in the `matplotlib.pyplot` module. (Note: can also do this directly from a list with the `hist()` function, but we want to use the `histogram()` function).
#
# First we'll import the module.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Now we can use the `bar()` function. It takes two arguments, `x` and `y`,  both lists:
# * `x` (list) are the _bins_ on the horizontal axis. The list can be of all numbers or all strings.
# * `y` (list of numbers): `y[i]` is the height of the bar labeled `x[i]`
#
# Example:

# %%
x = [-1, 0, 2, 3, 4]
y = [10,  2, 3, 4, 8]
plt.bar(x,y);

# %%
x = [-1, 0, 2, 3, 4]
y = [10,  2, 3, 4, 8]
plt.bar(x,y);

# %% [markdown]
# To use `bar()` to plot our dictionary, we'll use the `keys()` and `values()` methods, but with the results converted to list:

# %%
scores_hist.values()
# Out:
# dict_values([6, 3, 1, 2])

# %%
list(scores_hist.values())
# Out:
# [6, 3, 1, 2]

# %%
def plot_histogram(d):
    """ plot histogram data stored in dictionary d """
    plt.bar( list(d.keys()), list(d.values()))

# %%
plot_histogram(scores_hist)

# %% [markdown]
# We'll return to dictionaries and histograms later.

# %% [markdown]
# <div class="dyb">Finished here Wednesday</div>

# %% [markdown]
# # Arcane Interlude 8: Where are you coming from and where are you going to?
#
# This is a weekly break from the grind of learning how to program in Python, and just do something interesting. Explanations not included, but do ask if interested.
#
# The background is that, in Week 1, you completed a short survey, can included some details on where you are from, and where you last went on holiday. We used that data before, in Week 2. Let's visualise it now, using the geo-locator data from Week 3.

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import folium
from folium.plugins import MarkerCluster
import IPython

# %% [markdown]
# We'll load the data from the `2223-CS102-CS103-where.xlsx`. That is available only on Blackboard.

# %%
input_df = pd.read_excel ("2223-CS102-CS103-where.xlsx", na_filter = False);
print(input_df)
# Out:
#                          Home            Vacation
# 0                  Craughwell            Budapest
# 1                       Sligo              London
# 2                     Galway               Mexico
# 3         Castlebar, Co. Mayo   Lake Garda, Italy
# 4                      Galway
# ..                        ...                 ...
# 126                   Donegal           Amsterdam
# 127  Castlerea, co Roscommon                 Cork
# 128        Ballyhaise, Cavan.  Casalvieri, Italy.
# 129                   Renvyle              London
# 130                     Sligo              Malaga
#
# [131 rows x 2 columns]

# %%
geolocator = Nominatim(user_agent="cs103")

# %%
HomeList = input_df['Home'].tolist()
AwayList = input_df['Vacation'].tolist()

# %%
world_map = folium.Map(tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)

# %% [markdown]
# In the next cell, set `PlaceList` to either `HomeList` or `AwayList`

# %%
PlaceList = HomeList # PlaceList should be one of HomeList of AwayList
i=0
for place in PlaceList:
    i+=1
    location =  geolocator.geocode(place)
    if (location == None):
        print(f"{i:3d} *** Warning, could not find {place}")
    else:
        lat,lon = location.latitude, location.longitude
        print(f'{i:3d}: Adding {place} at ({lat},{lon})')
        folium.CircleMarker(location=[lat,lon], tooltip=place,popup=place, fill =True).add_to(marker_cluster)
# Out:
#   1: Adding Craughwell at (53.23229975,-8.738242527769714)
#   2: Adding Sligo at (54.2720696,-8.4751357)
#   3: Adding Galway  at (53.2744122,-9.0490601)
#   4: Adding Castlebar, Co. Mayo at (54.0206781,-9.3795406)
#   5: Adding Galway at (53.2744122,-9.0490601)
#   6: Adding Stamullen, Co. Meath at (53.6243097,-6.299414233369189)
#   7: Adding Co Clare  at (52.857257450000006,-8.937435925994537)
#   8: Adding Moycullen Co Galway  at (53.34358175,-9.155091764807365)
#   9: Adding Oranmore at (53.2725116,-8.9285692)
#  10: Adding Salthill Co Galway at (53.26323945,-9.072188840261315)
#  11: Adding Ennis, Co.Clare at (52.90827185,-8.91256338196766)
#  12: Adding Knocknacarra at (53.2687291,-9.1090937)
#  13: Adding Ramelton at (-36.9279703,174.73064298450686)
#  14: Adding Ennis at (32.3293111,-96.6252679)
#  15: Adding Galway  at (53.2744122,-9.0490601)
#  16: Adding Letterkenny  at (54.9517933,-7.7354381)
#  17: Adding Ballindine at (53.682822599999994,-8.940975026837634)
#  18: Adding Carlow at (52.69078865,-6.825145150844913)
#  19: Adding Roscommon at (44.3326932,-84.6165164)
#  20: Adding Trim,Meath at (53.5542857,-6.789775120801938)
#  21: Adding Galway at (53.2744122,-9.0490601)
#  22: Adding Galway at (53.2744122,-9.0490601)
#  23: Adding Oranmore at (53.2725116,-8.9285692)
#  24: Adding Athlone at (53.588234,-113.550846)
#  25: Adding Clonmel at (53.391658050000004,-6.273465224256768)
#  26: Adding Cross, Co Clare at (52.598056,-9.771667)
#  27: Adding Menlo  at (41.5199394,-94.4048002)
#  28: Adding Loughrea at (53.1988841,-8.56759562450425)
#  29: Adding Ballyshannon, Co Donegal at (54.517844800000006,-8.183979159241051)
#  30: Adding Loughrea at (53.1988841,-8.56759562450425)
#  31: Adding Ardrahan,Co.Galway at (53.15675,-8.8059911)
#  32: Adding Ennis, Clare at (52.8393222,-8.9752567)
#  33: Adding Castlebar at (53.8472417,-9.2879285)
#  34: Adding Galway  at (53.2744122,-9.0490601)
#  35: Adding Achill, Mayo at (53.9521419,-10.009394199277633)
#  36: Adding Nenagh, Tipperary at (52.860474,-8.1950245)
#  37: Adding Skibbereen west cork at (51.5495131,-9.2695629)
#  38: Adding Cologne, Germany at (50.938361,6.959974)
#  39: Adding Moycullen, Co Galway at (53.34358175,-9.155091764807365)
#  40: Adding Drumlish  at (53.81812325,-7.768459100741513)
#  41: Adding Caltra at (53.4355055,-8.4369796)
#  42 *** Warning, could not find The Dark Road, Ardrahan, Co. Galway
#  43: Adding Portumna  at (53.0936807,-8.226343702528549)
#  44: Adding Newport Co. Mayo at (53.8862912,-9.546796086284711)
#  45: Adding Ballymahon, Longford at (53.56353245,-7.764441528066919)
#  46: Adding Dublin at (53.3498006,-6.2602964)
#  47: Adding Ennis, Co.Clare at (52.90827185,-8.91256338196766)
#  48: Adding Prague at (50.0874654,14.4212535)
#  49: Adding Galway at (53.2744122,-9.0490601)
#  50: Adding Derry City County Derry at (54.9930177,-7.3127401)
#  51: Adding Castlebar, Mayo at (53.8472417,-9.2879285)
#  52: Adding Newmarket on Fergus at (52.755527,-8.910028)
#  53: Adding Mullingar Co Westmeath at (53.52545355,-7.337575632590402)
#  54: Adding Salthill, Galway at (53.26323945,-9.072188840261315)
#  55: Adding Islamabad at (33.6938118,73.0651511)
#  56: Adding Loughrea  at (53.1988841,-8.56759562450425)
#  57: Adding Newbridge  at (55.9391687,-3.4079986)
#  58: Adding Lismore, Co. Waterford at (52.0913573,-7.6203499)
#  59: Adding Ballyglass, Claremorris  at (53.639778899999996,-8.983534874782613)
#  60: Adding Dublin at (53.3498006,-6.2602964)
#  61: Adding Quin, Co. Clare  at (52.8190491,-8.8670162)
#  62: Adding Ballinasloe  at (53.3362881,-8.2402629)
#  63: Adding Togher, Louth at (53.8351661,-6.2986431)
#  64: Adding Cork  at (51.897077,-8.4654674)
#  65: Adding Laois at (52.9984575,-7.3980337750324185)
#  66: Adding La Coruña, Spain at (43.3709703,-8.3959425)
#  67: Adding Athenry  at (53.3013745,-8.7489782)
#  68: Adding Limerick city  at (52.648596049999995,-8.452318819134495)
#  69: Adding Craughwell at (53.23229975,-8.738242527769714)
#  70: Adding Leitrim at (54.140162200000006,-8.052478216276088)
#  71: Adding Kilkenny at (52.6510216,-7.2484948)
#  72: Adding Macroom, Cork  at (51.9081738,-8.966527650612132)
#  73: Adding Portlaois at (53.0277848,-7.2888721)
#  74: Adding Limerick  at (52.661252,-8.6301239)
#  75: Adding Baltinglass  at (52.93102035,-6.692783869258065)
#  76: Adding Southampton NY at (40.884267,-72.3895296)
#  77: Adding Headford  at (53.4692981,-9.104071988222008)
#  78: Adding ring, co. waterford at (52.048333,-7.585278)
#  79: Adding Ballinasloe  at (53.3362881,-8.2402629)
#  80: Adding Galway  at (53.2744122,-9.0490601)
#  81: Adding castledermot co kildare at (52.9099782,-6.8401423850938805)
#  82: Adding Sligo at (54.2720696,-8.4751357)
#  83: Adding Inverin Galway  at (53.241819250000006,-9.47730956809632)
#  84: Adding Wexford  at (52.46018745,-6.606515459159162)
#  85: Adding Tulla Clare  at (52.8666937,-8.7595259)
#  86: Adding Ennis at (32.3293111,-96.6252679)
#  87: Adding Tramore County Waterford  at (52.1835974,-7.1496198989537)
#  88: Adding Tuam at (53.5148196,-8.848874535285654)
#  89: Adding Galway at (53.2744122,-9.0490601)
#  90: Adding Athenry Galway  at (53.3013745,-8.7489782)
#  91: Adding Barna, Galway at (53.27042685,-9.11245047054324)
#  92: Adding Lahardane, Co. Mayo at (54.03197915,-9.318685349654888)
#  93: Adding Sligo at (54.2720696,-8.4751357)
#  94: Adding Barcelona, Spain at (41.3828939,2.1774322)
#  95: Adding Ballyshannon, Co. Donegal at (54.517844800000006,-8.183979159241051)
#  96: Adding Portlaoise  at (53.0368853,-7.3013754)
#  97: Adding Recess, Co.Galway at (53.4665017,-9.7256654)
#  98: Adding Tarbert, Co Kerry at (52.58098165,-9.372339225538571)
#  99: Adding Athlone at (53.588234,-113.550846)
# 100: Adding Ballyhaunis, Co Mayo at (53.7616068,-8.758238)
# 101: Adding Birdhill co.Tipperary at (52.766847999999996,-8.412064405760297)
# 102: Adding Tralee Kerry at (52.2692835,-9.7054085)
# 103: Adding Ballina, Co Mayo at (54.0206781,-9.3795406)
# 104: Adding Listowel, Co Kerry at (52.44744925,-9.48516429599222)
# 105: Adding Ballyhaunis Co Mayo  at (53.7616068,-8.758238)
# 106: Adding Limerick at (52.661252,-8.6301239)
# 107: Adding Oughterard, Galway at (53.4108247,-9.352359835993788)
# 108: Adding Granard, Co. Longford at (53.77804605,-7.496104812172997)
# 109: Adding Clifden at (53.4884916,-10.0210673)
# 110: Adding Monasterevin, Co.Kildare at (53.1454887,-7.06302)
# 111 *** Warning, could not find Baile na Gadaí
# 112: Adding New York  at (40.7127281,-74.0060152)
# 113: Adding Spiddal, Co.Galway  at (53.2443899,-9.3063031)
# 114: Adding Cabinteely, Dublin at (53.2612843,-6.1505691)
# 115: Adding Strabane, Co.Tyrone at (54.826115,-7.4627993)
# 116: Adding Granard, Co. Longford at (53.77804605,-7.496104812172997)
# 117: Adding Croghan, Co Roscommon at (53.91428645,-8.228109098166167)
# 118: Adding Kinvara, Co Galway at (53.12357765,-8.834268451180495)
# 119: Adding Galway City  at (53.284150600000004,-9.037836324751463)
# 120: Adding Annaghdown, Co Galway at (53.3866665,-9.068852)
# 121: Adding Athenry  at (53.3013745,-8.7489782)
# 122: Adding Kyiv at (50.4500336,30.5241361)
# 123: Adding Clifden, Co Galway at (53.4884916,-10.0210673)
# 124: Adding Corofin, Co Galway at (53.438364199999995,-8.885851148567287)
# 125: Adding Galway City at (53.284150600000004,-9.037836324751463)
# 126: Adding Galway at (53.2744122,-9.0490601)
# 127: Adding Donegal at (54.92075415,-7.952385214651309)
# 128: Adding Castlerea, co Roscommon  at (53.7614093,-8.4856622)
# 129: Adding Ballyhaise, Cavan. at (54.0470453,-7.3171962)
# 130: Adding Renvyle at (53.2877879,-6.134859368204489)
# 131: Adding Sligo at (54.2720696,-8.4751357)

# %%
world_map.fit_bounds(world_map.get_bounds(), padding=(30, 30))
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73986e09a2f74513ac26fd6c9db14353 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73986e09a2f74513ac26fd6c9db14353&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_73986e09a2f74513ac26fd6c9db14353 = L.map(
#                 &quot;map_73986e09a2f74513ac26fd6c9db14353&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1296cc7bb93d5ab3bf6a29868686ae29 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73986e09a2f74513ac26fd6c9db14353);
#
#
#             var marker_cluster_abda676d5c9d46caf6b79715fc662abb = L.markerClusterGroup(
#                 {}
#             );
#             map_73986e09a2f74513ac26fd6c9db14353.addLayer(marker_cluster_abda676d5c9d46caf6b79715fc662abb);
#
#
#             var circle_marker_8ce1499432c4e59b0dd989a6d5fb3d74 = L.circleMarker(
#                 [53.23229975, -8.738242527769714],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_abda676d5c9d46caf6b79715fc662abb);
#
#
#         var popup_b8210575e000165ff57ff589fdb4d7fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7701f423061354b5f2bb293d7f862400 = $(`&lt;div id=&quot;html_7701f423061354b5f2bb293d7f862400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Craughwell&lt;/div&gt;`)[0];
#             popup_b8210575e000165ff57ff589fdb4d7fd.setContent(html_7701f423061354b5f2bb293d7f862400);
#
#
#         circle_marker_8ce1499432c4e59b0dd989a6d5fb3d74.bindPopup(popup_b8210575e000165ff57ff589fdb4d7fd)
#         ;
#
#
#
#
#             circle_marker_8ce1499432c4e59b0dd989a6d5fb3d74.bindTooltip(
#                 `&lt;div&gt;
#                      Craughwell
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b3b582cd21dd290962bb225691162d51 = L.circleMarker(
#                 [54.2720696, -8.4751357],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_abda676d5c9d46caf6b79715fc662abb);
#
#
#         var popup_fb8701266355aa6bf24b6261e315206b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_13b92f5401a21f79585eca3aba1b9208 = $(`&lt;div id=&quot;html_13b92f5401a21f79585eca3aba1b9208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sligo&lt;/div&gt;`)[0];
#             popup_fb8701266355aa6bf24b6261e315206b.setContent(html_13b92f5401a21f79585eca3aba1b9208);
#
#
#         circle_marker_b3b582cd21dd290962bb225691162d51.bindPopup(popup_fb8701266355aa6bf24b6261e315206b)
#         ;
#
#
#
#
#             circle_marker_b3b582cd21dd290962bb225691162d51.bindTooltip(
#                 `&lt;div&gt;
#                      Sligo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_ad776966679b3c80699c85ec112ea425 = L.circleMarker(
#                 [53.2744122, -9.0490601],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &q

# %% [markdown]
# # Dictionaries and Histograms Again
#
# We had a function, `histogram` that creates a dictionary histogram of elements of a list or string.
#
# And we have a function, `plot_histogram()` that gives makes bar-chart of the data in the histogram.
#
# Let's test these by plotting the frequency of letters in a phrase, and then letters from the `words.txt` file.

# %% [markdown]
# ## Counting letters in a phrase
# Our phrase is chosen because it contains all 26 letters.

# %%
phrase = "Jackie will budget for the most expensive Zoology equipment"

# %% [markdown]
# Before proceeding, we will "clean" this data as follows:
# 1. Change all letters to lower-case, with `.tolower()`
# 2. Remove spaces. We'll use the `.replace()` method for that.
# 3. Apply `sorted()` which arranges the letters alphabetically, and also converts to a list.

# %%
phrase.lower()
# Out:
# 'jackie will budget for the most expensive zoology equipment'

# %%
phrase.lower().replace(" ","")
# Out:
# 'jackiewillbudgetforthemostexpensivezoologyequipment'

# %%
phrase = sorted(phrase.lower().replace(" ",""))

# %%
print(phrase)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'f', 'g', 'g', 'h', 'i', 'i', 'i', 'i', 'j', 'k', 'l', 'l', 'l', 'm', 'm', 'n', 'n', 'o', 'o', 'o', 'o', 'o', 'p', 'p', 'q', 'r', 's', 's', 't', 't', 't', 't', 'u', 'u', 'v', 'w', 'x', 'y', 'z']

# %% [markdown]
# Now make the histogram dictionary, and plot it.

# %%
phrase_histogram = histogram(phrase)

# %%
plot_histogram(phrase_histogram)

# %% [markdown]
# ## Counting letters in a file
#
# The previous example wasn't very realistic. To get somewhat more realistic results, we'll take data from the `words.txt` file we used in Week 8.

# %%
file_name = "words.txt"
try:
    fin = open(file_name)
except:
    print(f"Sorry - could not open {file_name}.")

# %%
all_the_words = fin.read()
all_the_words[:25]
# Out:
# 'aa\naah\naahed\naahing\naahs\n'

# %% [markdown]
# The `.read()` method reads the entire contents of the file into a single string, including all `\n`. So, we'll remove them.

# %%
all_the_words = sorted(all_the_words.replace('\n',''))

# %%
letters_histogram = histogram(all_the_words)
plot_histogram(letters_histogram)

# %% [markdown]
# ## Reverse look-up
#
# Given a dictionary a `look-up` operation returns the value for a given key.
#
# Example:

# %%
capitals = {"Ireland":"Dublin", "Pakistan":"Islamabad", "Spain":"Madrid", 
            "USA":"Washington", "Ukraine":"Kyiv", "Czechia":"Prague"}

# %%
print(capitals['Spain'])
# Out:
# Madrid

# %% [markdown]
# A **reverse look-up** returns a key that is paired with a particular value. For example, a reverse lookup of `Madrid` in this dictionary should yield `Spain`.
#
# Here is a function that does this (taken from the book). It uses the `raise` instruction, which allows us to control error messages.

# %%
def reverse_lookup(d, v):
    for k in d:  # iterates over keys
        if d[k] == v:
            return k
    raise LookupError("Value not found in dictionary")

# %%
reverse_lookup(capitals, "Madrid")
# Out:
# 'Spain'

# %% [markdown]
# If we try to find a non-existent value, we get an error such as this:
# ```python
# reverse_lookup(capitals, "Lisbon")
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Input In [88], in <cell line: 1>()
# ----> 1 reverse_lookup(capitals, "Lisbon")
#
# Input In [85], in reverse_lookup(d, v)
#       3     if d[k] == v:
#       4         return k
# ----> 5 raise LookupError("Value not found in dictionary")
#
# LookupError: Value not found in dictionary
# ```

# %% [markdown]
# ## Inverting a dictionary
#
# (See Section 11.5 of Think Python).
#
# Occasionally, we need to _invert_ a dictionary. That is, we make a new dictionary where if `k:v` is a `key:value` pair in original dictionary, then `v:k` is a  `key:value` in the new one. For example,

# %%
print(capitals)
# Out:
# {'Ireland': 'Dublin', 'Pakistan': 'Islamabad', 'Spain': 'Madrid', 'USA': 'Washington', 'Ukraine': 'Kyiv', 'Czechia': 'Prague'}

# %% [markdown]
# if inverted would be like:

# %%
inv_cap = {'Cork': 'Ireland', 'Dublin':'Ireland',  'Islamabad':'Pakistan',  'Madrid':'Spain', 'Washington':'USA',
 'Kyiv':'Ukraine', 'Prague':'Czechia'}
print(inv_cap)
# Out:
# {'Cork': 'Ireland', 'Dublin': 'Ireland', 'Islamabad': 'Pakistan', 'Madrid': 'Spain', 'Washington': 'USA', 'Kyiv': 'Ukraine', 'Prague': 'Czechia'}

# %% [markdown]
# But there is a catch! In a dictionary, each key is unique (i.e., it can be repeated with a different value). But the same values can be paired with different keys. Recall the `phrase_histogram` from earlier:

# %%
print(phrase_histogram)
# Out:
# {'a': 1, 'b': 1, 'c': 1, 'd': 1, 'e': 8, 'f': 1, 'g': 2, 'h': 1, 'i': 4, 'j': 1, 'k': 1, 'l': 3, 'm': 2, 'n': 2, 'o': 5, 'p': 2, 'q': 1, 'r': 1, 's': 2, 't': 4, 'u': 2, 'v': 1, 'w': 1, 'x': 1, 'y': 1, 'z': 1}

# %% [markdown]
# Numerous keys (=letters) have the same value. E.g, `a`, `b`, `c` and many others have the value `1`.
#
# **Question**: if we  were to invert this dictionary, what would be the value of the key `1`?
#
# **Answer**: a `list` of all keys from the original dictionary that were paired with `1`.

# %%
def invert_dict(d):
    """ Invert a dictionary. If k:v is a pair in d, then the
    returned dictionary has v as a key, and k in a list paired with it.
    """
    inverse = dict()
    for key in d:
        val = d[key]
        if val not in inverse:
            inverse[val] = [key]
        else:
            inverse[val] += [key]
    return inverse

# %%
invert_dict(capitals)
# Out:
# {'Dublin': ['Ireland'],
#  'Islamabad': ['Pakistan'],
#  'Madrid': ['Spain'],
#  'Washington': ['USA'],
#  'Kyiv': ['Ukraine'],
#  'Prague': ['Czechia']}

# %%
(invert_dict(phrase_histogram))
# Out:
# {1: ['a',
#   'b',
#   'c',
#   'd',
#   'f',
#   'h',
#   'j',
#   'k',
#   'q',
#   'r',
#   'v',
#   'w',
#   'x',
#   'y',
#   'z'],
#  8: ['e'],
#  2: ['g', 'm', 'n', 'p', 's', 'u'],
#  4: ['i', 't'],
#  3: ['l'],
#  5: ['o']}

# %% [markdown]
# <div class="dby">Finished here Friday</div>

# %% [markdown]
# # Example : Reverse Words
#
# In our last example, we'll make a list of words which, if reversed, give another work (in the `words.txt` file).

# %% [markdown]
# ## Word reverser
#
# It will be useful to have a function that returns  a string reversed.

# %%
def reverse(word):
    return word[::-1]

# %%
reverse("lamina")
# Out:
# 'animal'

# %%
reverse("python")
# Out:
# 'nohtyp'

# %% [markdown]
# Now we'll read in all the words from `words.txt`, as elements of a `list`.

# %%
fin = open("words.txt")
all_the_words = fin.read()
list_of_words = all_the_words.split()

# %% [markdown]
# Next make an empty dictionary. Then for each word in the list, check if its reverse is also in the list. If it is, add these as a key:pair to the dictionary. (Note: this is quite slow).

# %%
reversable = dict()
for w in list_of_words[:3000]:
    if (reverse(w) in list_of_words) and (w != reverse(w)):
        #print(w)
        reversable[w]=reverse(w)

# %%
reversable
# Out:
# {'abut': 'tuba',
#  'ad': 'da',
#  'ados': 'soda',
#  'agar': 'raga',
#  'agas': 'saga',
#  'agenes': 'senega',
#  'ah': 'ha',
#  'aider': 'redia',
#  'airts': 'stria',
#  'ajar': 'raja',
#  'alif': 'fila',
#  'am': 'ma',
#  'amen': 'nema'}

# %% [markdown]
# This last example is based on Exercise 11.5 from the text. But that one is more interesting: it compiles lists of "cycled" word matches.
# More about lists and files next week!

# %% [markdown]
# <div class="dby">The end</div>
